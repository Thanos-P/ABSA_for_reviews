# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
from glove import *
import myUtils

import pandas as pd
from pandas.io.json._normalize import nested_to_record
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn import metrics

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# **Load GloVe model and dataset**

# %%
glove_model = GloveModel.from_pretrained('../trained_models/el.glove.300.txt')

# %%
review_dict = myUtils.read_json_v2('../data/reviews_revision.json')
reviews = pd.DataFrame.from_dict(nested_to_record(review_dict, sep='_'))
reviews.drop(columns='_id_$oid', inplace=True)

# Drop columns that will not be used
reviews.drop(columns=['meta_product_name',\
                      'meta_review_pros', 'meta_review_so-so', 'meta_review_cons'], inplace=True)
# Drop all product types except top 4 with most instances
reviews.drop(index=reviews[(reviews['meta_product_type'] != 'Κινητά Τηλέφωνα') & \
                           (reviews['meta_product_type'] != 'Gaming Headsets') & \
                           (reviews['meta_product_type'] != 'PS4 Games') & \
                           (reviews['meta_product_type'] != 'Activity Trackers')].index.tolist(),
             inplace=True)

# %% [markdown]
# **Get ids from words using GloVe model**

# %%
reviews['ids'] = reviews['text'].apply(glove_model.string_to_ids)
reviews['ids_length'] = reviews['ids'].apply(len)

# %% [markdown]
# **Remove outliers (entries with very long length)**

# %%
q_hi = reviews['ids_length'].quantile(0.95)
reviews = reviews[reviews['ids_length'] < q_hi].reset_index(drop=True)

# %%
reviews['ids_length'].describe()
# Out:
# count    588.000000
# mean      68.221088
# std       48.919174
# min        5.000000
# 25%       32.000000
# 50%       54.000000
# 75%       92.000000
# max      221.000000
# Name: ids_length, dtype: float64

# %%
reviews.sample(5)
# Out:
#                                                   text  meta_product_type  \
# 136  Έχει την πλάκα του μέχρι ένα σημείο γιατί σε β...  Activity Trackers
# 319  Παρηγγείλα τα ακουστικά Zeroground μετά από ολ...    Gaming Headsets
# 178  Για έναν μέσο χρήστη είναι υπέρ αρκετό!! Η μπα...    Κινητά Τηλέφωνα
# 219  Φοβερό παιχνίδι. Παρότι δεν είμαι φανατικός με...          PS4 Games
# 472  Ίσως το χειρότερο κινητό τηλέφωνο έφυγα από τη...    Κινητά Τηλέφωνα
#
#     meta_review_sentiment                                                ids  \
# 136              positive  [43, 9, 3010, 5, 95, 36, 348, 96, 16, 2882, 41...
# 319               neutral  [39714, 14, 9689, 69, 13, 179, 31, 1810, 4762,...
# 178              positive  [11, 137, 928, 1542, 17, 793, 2857, 40, 40, 8,...
# 219              positive  [9341, 380, 2, 2884, 28, 338, 25036, 10, 4, 63...
# 472              negative  [301, 4, 3885, 2224, 1397, 16265, 13, 9, 4505,...
#
#      ids_length
# 136          97
# 319          59
# 178          47
# 219          31
# 472          52

# %% [markdown]
# **Pad ids of each entry to match their length**

# %%
padded_ids = keras.preprocessing.sequence.pad_sequences(
    reviews['ids'].to_numpy(), padding="post", value=0
)

# %% [markdown]
# **Transform target labels to one-hot encoding**

# %%
onehot = OneHotEncoder(sparse=False)
encoded_sentiment = onehot.fit_transform(reviews['meta_review_sentiment'].values.reshape(-1,1))

# %% [markdown]
# **Fit model**

# %%
# Define the K-fold Cross Validator
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
acc_per_fold = []
loss_per_fold = []
for train, test in kfold.split(padded_ids, encoded_sentiment):

    # Define the model architecture
    embeddings_layer = keras.layers.Embedding(
        input_dim=glove_model.emb_norm.shape[0], output_dim=glove_model.emb_norm.shape[1],
        weights=[glove_model.emb_norm], name='embeddings', mask_zero=True
    )
    model = keras.Sequential([
        keras.layers.InputLayer(input_shape=(padded_ids.shape[1],), name='inputs'),
        embeddings_layer,
        keras.layers.Bidirectional(tf.keras.layers.LSTM(128), name='BLSTM'),
        keras.layers.Dense(3, activation='softmax', name='linear_softmax')
    ])

    # Compile the model
    model.compile(loss=keras.losses.CategoricalCrossentropy(),
                  optimizer=keras.optimizers.Adam(1e-4),
                  metrics=keras.metrics.CategoricalAccuracy())

    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1,
                                                      restore_best_weights=True)
    history = model.fit(padded_ids[train], encoded_sentiment[train],
                        validation_split=0.25,
                        batch_size=32,
                        epochs=50,
                        callbacks=[early_stopping])

    # Generate generalization metrics
    scores = model.evaluate(padded_ids[test], encoded_sentiment[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/50
# 11/11 [==============================] - 22s 2s/step - loss: 1.0954 - categorical_accuracy: 0.3778 - val_loss: 1.0959 - val_categorical_accuracy: 0.3220
# Epoch 2/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0854 - categorical_accuracy: 0.4631 - val_loss: 1.0922 - val_categorical_accuracy: 0.3220
# Epoch 3/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0774 - categorical_accuracy: 0.4347 - val_loss: 1.0887 - val_categorical_accuracy: 0.3390
# Epoch 4/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0699 - categorical_accuracy: 0.4460 - val_loss: 1.0854 - val_categorical_accuracy: 0.3559
# Epoch 5/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0624 - categorical_accuracy: 0.4602 - val_loss: 1.0815 - val_categorical_accuracy: 0.3559
# Epoch 6/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0534 - categorical_accuracy: 0.4858 - val_loss: 1.0783 - val_categorical_accuracy: 0.3898
# Epoch 7/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0428 - categorical_accuracy: 0.5028 - val_loss: 1.0763 - val_categorical_accuracy: 0.3644
# Epoch 8/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0298 - categorical_accuracy: 0.5284 - val_loss: 1.0714 - val_categorical_accuracy: 0.4068
# Epoch 9/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0116 - categorical_accuracy: 0.5653 - val_loss: 1.0614 - val_categorical_accuracy: 0.4322
# Epoch 10/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.9850 - categorical_accuracy: 0.5795 - val_loss: 1.0503 - val_categorical_accuracy: 0.4237
# Epoch 11/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.9375 - categorical_accuracy: 0.6449 - val_loss: 0.9835 - val_categorical_accuracy: 0.5593
# Epoch 12/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.8322 - categorical_accuracy: 0.6903 - val_loss: 0.9386 - val_categorical_accuracy: 0.5424
# Epoch 13/50
# 11/11 [==============================] - 19s 2s/step - loss: 0.7535 - categorical_accuracy: 0.7472 - val_loss: 1.0034 - val_categorical_accuracy: 0.5169
# Epoch 14/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.6875 - categorical_accuracy: 0.8153 - val_loss: 0.8997 - val_categorical_accuracy: 0.6102
# Epoch 15/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.5815 - categorical_accuracy: 0.8125 - val_loss: 0.9518 - val_categorical_accuracy: 0.5678
# Epoch 16/50
# 11/11 [==============================] - 17s 2s/step - loss: 0.5188 - categorical_accuracy: 0.8693 - val_loss: 0.9317 - val_categorical_accuracy: 0.6610
# Epoch 17/50
# 11/11 [==============================] - 23s 2s/step - loss: 0.4894 - categorical_accuracy: 0.8722 - val_loss: 1.0234 - val_categorical_accuracy: 0.5932
# Epoch 18/50
# 11/11 [==============================] - 20s 2s/step - loss: 0.4297 - categorical_accuracy: 0.9119 - val_loss: 0.9780 - val_categorical_accuracy: 0.6017
# Epoch 19/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.3821 - categorical_accuracy: 0.9034 - val_loss: 0.9816 - val_categorical_accuracy: 0.6017
# Epoch 20/50
# 11/11 [==============================] - 17s 2s/step - loss: 0.3238 - categorical_accuracy: 0.9347 - val_loss: 1.0936 - val_categorical_accuracy: 0.6017
# Epoch 21/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2769 - categorical_accuracy: 0.9403 - val_loss: 1.0521 - val_categorical_accuracy: 0.5678
# Epoch 22/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.2505 - categorical_accuracy: 0.9432 - val_loss: 1.1613 - val_categorical_accuracy: 0.5763
# Epoch 23/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2386 - categorical_accuracy: 0.9517 - val_loss: 1.2925 - val_categorical_accuracy: 0.5424
# Epoch 24/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2048 - categorical_accuracy: 0.9631 - val_loss: 1.3185 - val_categorical_accuracy: 0.5254
# Restoring model weights from the end of the best epoch.
# Epoch 00024: early stopping
# Score for fold 1: loss of 0.9467569589614868; categorical_accuracy of 51.69491767883301%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/50
# 11/11 [==============================] - 20s 2s/step - loss: 1.0988 - categorical_accuracy: 0.3466 - val_loss: 1.0962 - val_categorical_accuracy: 0.3559
# Epoch 2/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0905 - categorical_accuracy: 0.4432 - val_loss: 1.0930 - val_categorical_accuracy: 0.3983
# Epoch 3/50
# 11/11 [==============================] - 15s 1s/step - loss: 1.0832 - categorical_accuracy: 0.5256 - val_loss: 1.0917 - val_categorical_accuracy: 0.3644
# Epoch 4/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0762 - categorical_accuracy: 0.5597 - val_loss: 1.0897 - val_categorical_accuracy: 0.4153
# Epoch 5/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0683 - categorical_accuracy: 0.5682 - val_loss: 1.0871 - val_categorical_accuracy: 0.4237
# Epoch 6/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0601 - categorical_accuracy: 0.6278 - val_loss: 1.0848 - val_categorical_accuracy: 0.4237
# Epoch 7/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0494 - categorical_accuracy: 0.6847 - val_loss: 1.0792 - val_categorical_accuracy: 0.4746
# Epoch 8/50
# 11/11 [==============================] - 16s 1s/step - loss: 1.0363 - categorical_accuracy: 0.7415 - val_loss: 1.0764 - val_categorical_accuracy: 0.4831
# Epoch 9/50
# 11/11 [==============================] - 15s 1s/step - loss: 1.0198 - categorical_accuracy: 0.7642 - val_loss: 1.0697 - val_categorical_accuracy: 0.4915
# Epoch 10/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.9951 - categorical_accuracy: 0.7812 - val_loss: 1.0620 - val_categorical_accuracy: 0.4576
# Epoch 11/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.9550 - categorical_accuracy: 0.7699 - val_loss: 1.0459 - val_categorical_accuracy: 0.4661
# Epoch 12/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.8706 - categorical_accuracy: 0.7699 - val_loss: 0.9663 - val_categorical_accuracy: 0.5508
# Epoch 13/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.7733 - categorical_accuracy: 0.7301 - val_loss: 1.0090 - val_categorical_accuracy: 0.5254
# Epoch 14/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.7084 - categorical_accuracy: 0.7812 - val_loss: 0.9572 - val_categorical_accuracy: 0.5169
# Epoch 15/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.6428 - categorical_accuracy: 0.7898 - val_loss: 0.9847 - val_categorical_accuracy: 0.5763
# Epoch 16/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.5673 - categorical_accuracy: 0.8523 - val_loss: 1.0671 - val_categorical_accuracy: 0.5593
# Epoch 17/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.4815 - categorical_accuracy: 0.8608 - val_loss: 1.1104 - val_categorical_accuracy: 0.5593
# Epoch 18/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.4204 - categorical_accuracy: 0.8977 - val_loss: 1.1685 - val_categorical_accuracy: 0.5678
# Epoch 19/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.3603 - categorical_accuracy: 0.9205 - val_loss: 1.1946 - val_categorical_accuracy: 0.5593
# Epoch 20/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.3490 - categorical_accuracy: 0.9261 - val_loss: 1.3601 - val_categorical_accuracy: 0.4492
# Epoch 21/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.5112 - categorical_accuracy: 0.8551 - val_loss: 1.0954 - val_categorical_accuracy: 0.5593
# Epoch 22/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.4148 - categorical_accuracy: 0.8949 - val_loss: 0.9957 - val_categorical_accuracy: 0.5254
# Epoch 23/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.3647 - categorical_accuracy: 0.9176 - val_loss: 0.9433 - val_categorical_accuracy: 0.5847
# Epoch 24/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.3034 - categorical_accuracy: 0.9517 - val_loss: 1.0048 - val_categorical_accuracy: 0.5593
# Epoch 25/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.2396 - categorical_accuracy: 0.9602 - val_loss: 0.9682 - val_categorical_accuracy: 0.5932
# Epoch 26/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.2119 - categorical_accuracy: 0.9602 - val_loss: 1.1136 - val_categorical_accuracy: 0.5932
# Epoch 27/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.1690 - categorical_accuracy: 0.9716 - val_loss: 1.2261 - val_categorical_accuracy: 0.5678
# Epoch 28/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.1533 - categorical_accuracy: 0.9744 - val_loss: 1.2302 - val_categorical_accuracy: 0.5678
# Epoch 29/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.1416 - categorical_accuracy: 0.9773 - val_loss: 1.2487 - val_categorical_accuracy: 0.5763
# Epoch 30/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.1286 - categorical_accuracy: 0.9773 - val_loss: 1.3097 - val_categorical_accuracy: 0.5763
# Epoch 31/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.1328 - categorical_accuracy: 0.9773 - val_loss: 1.2880 - val_categorical_accuracy: 0.5847
# Epoch 32/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.1370 - categorical_accuracy: 0.9744 - val_loss: 1.2323 - val_categorical_accuracy: 0.5763
# Epoch 33/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.1189 - categorical_accuracy: 0.9830 - val_loss: 1.3677 - val_categorical_accuracy: 0.6102
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# Score for fold 2: loss of 0.8705316185951233; categorical_accuracy of 63.55932354927063%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/50
# 11/11 [==============================] - 19s 1s/step - loss: 1.0984 - categorical_accuracy: 0.3239 - val_loss: 1.0958 - val_categorical_accuracy: 0.3983
# Epoch 2/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0879 - categorical_accuracy: 0.4460 - val_loss: 1.0981 - val_categorical_accuracy: 0.3305
# Epoch 3/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0804 - categorical_accuracy: 0.4006 - val_loss: 1.1016 - val_categorical_accuracy: 0.2966
# Epoch 4/50
# 11/11 [==============================] - 14s 1s/step - loss: 1.0723 - categorical_accuracy: 0.3864 - val_loss: 1.1001 - val_categorical_accuracy: 0.2966
# Epoch 5/50
# 11/11 [==============================] - 16s 1s/step - loss: 1.0657 - categorical_accuracy: 0.3920 - val_loss: 1.1030 - val_categorical_accuracy: 0.2966
# Epoch 6/50
# 11/11 [==============================] - 16s 1s/step - loss: 1.0548 - categorical_accuracy: 0.4062 - val_loss: 1.0982 - val_categorical_accuracy: 0.3051
# Epoch 7/50
# 11/11 [==============================] - 16s 1s/step - loss: 1.0441 - categorical_accuracy: 0.5000 - val_loss: 1.0926 - val_categorical_accuracy: 0.3136
# Epoch 8/50
# 11/11 [==============================] - 15s 1s/step - loss: 1.0301 - categorical_accuracy: 0.5511 - val_loss: 1.0858 - val_categorical_accuracy: 0.3729
# Epoch 9/50
# 11/11 [==============================] - 15s 1s/step - loss: 1.0097 - categorical_accuracy: 0.5653 - val_loss: 1.0861 - val_categorical_accuracy: 0.3305
# Epoch 10/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.9718 - categorical_accuracy: 0.5682 - val_loss: 1.0713 - val_categorical_accuracy: 0.3559
# Epoch 11/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.9207 - categorical_accuracy: 0.7557 - val_loss: 1.0075 - val_categorical_accuracy: 0.5169
# Epoch 12/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.8476 - categorical_accuracy: 0.8153 - val_loss: 0.9681 - val_categorical_accuracy: 0.5508
# Epoch 13/50
# 11/11 [==============================] - 16s 1s/step - loss: 0.7669 - categorical_accuracy: 0.7869 - val_loss: 0.9534 - val_categorical_accuracy: 0.5508
# Epoch 14/50
# 11/11 [==============================] - 17s 2s/step - loss: 0.6916 - categorical_accuracy: 0.7727 - val_loss: 0.9543 - val_categorical_accuracy: 0.5763
# Epoch 15/50
# 11/11 [==============================] - 17s 2s/step - loss: 0.6074 - categorical_accuracy: 0.8239 - val_loss: 0.9323 - val_categorical_accuracy: 0.5424
# Epoch 16/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.5406 - categorical_accuracy: 0.8494 - val_loss: 1.0243 - val_categorical_accuracy: 0.5085
# Epoch 17/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.5097 - categorical_accuracy: 0.8466 - val_loss: 1.0427 - val_categorical_accuracy: 0.5085
# Epoch 18/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.4483 - categorical_accuracy: 0.8693 - val_loss: 0.9819 - val_categorical_accuracy: 0.5424
# Epoch 19/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.4027 - categorical_accuracy: 0.8949 - val_loss: 0.9669 - val_categorical_accuracy: 0.5593
# Epoch 20/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.3351 - categorical_accuracy: 0.9148 - val_loss: 1.1685 - val_categorical_accuracy: 0.5678
# Epoch 21/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2969 - categorical_accuracy: 0.9261 - val_loss: 1.2252 - val_categorical_accuracy: 0.5593
# Epoch 22/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.3046 - categorical_accuracy: 0.9233 - val_loss: 0.9836 - val_categorical_accuracy: 0.5593
# Epoch 23/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2697 - categorical_accuracy: 0.9545 - val_loss: 1.2603 - val_categorical_accuracy: 0.5678
# Epoch 24/50
# 11/11 [==============================] - 14s 1s/step - loss: 0.2643 - categorical_accuracy: 0.9347 - val_loss: 1.2493 - val_categorical_accuracy: 0.5678
# Epoch 25/50
# 11/11 [==============================] - 15s 1s/step - loss: 0.2312 - categorical_accuracy: 0.9688 - val_loss: 1.2294 - val_categorical_accuracy: 0.5339
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# Score for fold 3: loss of 0.8849905729293823; categorical_accuracy of 65.25423526763916%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/50
# 12/12 [==============================] - 25s 2s/step - loss: 1.1009 - categorical_accuracy: 0.3456 - val_loss: 1.0938 - val_categorical_accuracy: 0.3898
# Epoch 2/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0907 - categorical_accuracy: 0.4051 - val_loss: 1.0942 - val_categorical_accuracy: 0.3305
# Epoch 3/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0834 - categorical_accuracy: 0.3853 - val_loss: 1.0931 - val_categorical_accuracy: 0.3390
# Epoch 4/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0777 - categorical_accuracy: 0.4051 - val_loss: 1.0939 - val_categorical_accuracy: 0.3220
# Epoch 5/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0718 - categorical_accuracy: 0.4618 - val_loss: 1.0938 - val_categorical_accuracy: 0.3305
# Epoch 6/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0666 - categorical_accuracy: 0.5382 - val_loss: 1.0948 - val_categorical_accuracy: 0.3559
# Epoch 7/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0595 - categorical_accuracy: 0.5212 - val_loss: 1.0915 - val_categorical_accuracy: 0.3729
# Epoch 8/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0489 - categorical_accuracy: 0.5637 - val_loss: 1.0859 - val_categorical_accuracy: 0.3390
# Epoch 9/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0377 - categorical_accuracy: 0.5184 - val_loss: 1.0826 - val_categorical_accuracy: 0.3390
# Epoch 10/50
# 12/12 [==============================] - 18s 1s/step - loss: 1.0234 - categorical_accuracy: 0.6062 - val_loss: 1.0756 - val_categorical_accuracy: 0.3814
# Epoch 11/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0044 - categorical_accuracy: 0.6657 - val_loss: 1.0671 - val_categorical_accuracy: 0.3729
# Epoch 12/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.9847 - categorical_accuracy: 0.5666 - val_loss: 1.0423 - val_categorical_accuracy: 0.4492
# Epoch 13/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.9484 - categorical_accuracy: 0.8300 - val_loss: 1.0137 - val_categorical_accuracy: 0.5169
# Epoch 14/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.9029 - categorical_accuracy: 0.7535 - val_loss: 0.9984 - val_categorical_accuracy: 0.5254
# Epoch 15/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.9112 - categorical_accuracy: 0.6742 - val_loss: 0.9751 - val_categorical_accuracy: 0.6017
# Epoch 16/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.8033 - categorical_accuracy: 0.8499 - val_loss: 0.8909 - val_categorical_accuracy: 0.5678
# Epoch 17/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.7070 - categorical_accuracy: 0.7932 - val_loss: 0.8455 - val_categorical_accuracy: 0.6525
# Epoch 18/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.6325 - categorical_accuracy: 0.8385 - val_loss: 0.8918 - val_categorical_accuracy: 0.6356
# Epoch 19/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.5659 - categorical_accuracy: 0.8584 - val_loss: 0.8467 - val_categorical_accuracy: 0.6525
# Epoch 20/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.4867 - categorical_accuracy: 0.8895 - val_loss: 0.9417 - val_categorical_accuracy: 0.5678
# Epoch 21/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.4339 - categorical_accuracy: 0.8952 - val_loss: 1.0338 - val_categorical_accuracy: 0.5932
# Epoch 22/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.3664 - categorical_accuracy: 0.9150 - val_loss: 1.2381 - val_categorical_accuracy: 0.5508
# Epoch 23/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.5124 - categorical_accuracy: 0.8045 - val_loss: 1.1934 - val_categorical_accuracy: 0.5254
# Epoch 24/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.4812 - categorical_accuracy: 0.8669 - val_loss: 0.9749 - val_categorical_accuracy: 0.5678
# Epoch 25/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.4964 - categorical_accuracy: 0.9263 - val_loss: 0.7974 - val_categorical_accuracy: 0.6780
# Epoch 26/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.4289 - categorical_accuracy: 0.9348 - val_loss: 0.7971 - val_categorical_accuracy: 0.6610
# Epoch 27/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.3729 - categorical_accuracy: 0.9518 - val_loss: 0.8253 - val_categorical_accuracy: 0.6186
# Epoch 28/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.3125 - categorical_accuracy: 0.9575 - val_loss: 0.7843 - val_categorical_accuracy: 0.6695
# Epoch 29/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.2631 - categorical_accuracy: 0.9575 - val_loss: 0.8085 - val_categorical_accuracy: 0.6525
# Epoch 30/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.2295 - categorical_accuracy: 0.9688 - val_loss: 0.8883 - val_categorical_accuracy: 0.6356
# Epoch 31/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.1993 - categorical_accuracy: 0.9745 - val_loss: 0.9431 - val_categorical_accuracy: 0.6271
# Epoch 32/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.1756 - categorical_accuracy: 0.9802 - val_loss: 1.0088 - val_categorical_accuracy: 0.6271
# Epoch 33/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.1703 - categorical_accuracy: 0.9802 - val_loss: 1.1056 - val_categorical_accuracy: 0.6356
# Epoch 34/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.1475 - categorical_accuracy: 0.9858 - val_loss: 1.1496 - val_categorical_accuracy: 0.6186
# Epoch 35/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.1376 - categorical_accuracy: 0.9858 - val_loss: 1.1648 - val_categorical_accuracy: 0.6271
# Epoch 36/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.1251 - categorical_accuracy: 0.9915 - val_loss: 1.2691 - val_categorical_accuracy: 0.6017
# Epoch 37/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.1165 - categorical_accuracy: 0.9915 - val_loss: 1.2686 - val_categorical_accuracy: 0.6186
# Epoch 38/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.1322 - categorical_accuracy: 0.9858 - val_loss: 1.3004 - val_categorical_accuracy: 0.6017
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# Score for fold 4: loss of 0.8941837549209595; categorical_accuracy of 61.538463830947876%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/50
# 12/12 [==============================] - 24s 2s/step - loss: 1.1024 - categorical_accuracy: 0.3173 - val_loss: 1.1006 - val_categorical_accuracy: 0.2797
# Epoch 2/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0916 - categorical_accuracy: 0.3824 - val_loss: 1.0987 - val_categorical_accuracy: 0.3220
# Epoch 3/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0851 - categorical_accuracy: 0.3626 - val_loss: 1.1000 - val_categorical_accuracy: 0.3305
# Epoch 4/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0788 - categorical_accuracy: 0.3654 - val_loss: 1.0995 - val_categorical_accuracy: 0.3305
# Epoch 5/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0730 - categorical_accuracy: 0.3683 - val_loss: 1.0995 - val_categorical_accuracy: 0.3305
# Epoch 6/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0647 - categorical_accuracy: 0.3824 - val_loss: 1.0920 - val_categorical_accuracy: 0.3305
# Epoch 7/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0578 - categorical_accuracy: 0.3966 - val_loss: 1.0913 - val_categorical_accuracy: 0.3305
# Epoch 8/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0476 - categorical_accuracy: 0.4306 - val_loss: 1.0883 - val_categorical_accuracy: 0.3305
# Epoch 9/50
# 12/12 [==============================] - 16s 1s/step - loss: 1.0376 - categorical_accuracy: 0.4448 - val_loss: 1.0869 - val_categorical_accuracy: 0.3390
# Epoch 10/50
# 12/12 [==============================] - 18s 2s/step - loss: 1.0255 - categorical_accuracy: 0.4731 - val_loss: 1.0800 - val_categorical_accuracy: 0.3475
# Epoch 11/50
# 12/12 [==============================] - 17s 1s/step - loss: 1.0099 - categorical_accuracy: 0.6289 - val_loss: 1.0649 - val_categorical_accuracy: 0.4746
# Epoch 12/50
# 12/12 [==============================] - 18s 2s/step - loss: 0.9833 - categorical_accuracy: 0.7025 - val_loss: 1.0545 - val_categorical_accuracy: 0.4407
# Epoch 13/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.9458 - categorical_accuracy: 0.5779 - val_loss: 1.0201 - val_categorical_accuracy: 0.4576
# Epoch 14/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.8927 - categorical_accuracy: 0.6714 - val_loss: 0.9484 - val_categorical_accuracy: 0.5254
# Epoch 15/50
# 12/12 [==============================] - 18s 2s/step - loss: 0.8072 - categorical_accuracy: 0.7054 - val_loss: 0.9521 - val_categorical_accuracy: 0.5593
# Epoch 16/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.7261 - categorical_accuracy: 0.6997 - val_loss: 0.8619 - val_categorical_accuracy: 0.5847
# Epoch 17/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.6371 - categorical_accuracy: 0.8187 - val_loss: 0.8511 - val_categorical_accuracy: 0.6186
# Epoch 18/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.5822 - categorical_accuracy: 0.7989 - val_loss: 0.9419 - val_categorical_accuracy: 0.5763
# Epoch 19/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.5286 - categorical_accuracy: 0.8640 - val_loss: 0.9094 - val_categorical_accuracy: 0.6017
# Epoch 20/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.4644 - categorical_accuracy: 0.8527 - val_loss: 1.0144 - val_categorical_accuracy: 0.5763
# Epoch 21/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.4131 - categorical_accuracy: 0.8810 - val_loss: 0.9674 - val_categorical_accuracy: 0.6186
# Epoch 22/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.3978 - categorical_accuracy: 0.8810 - val_loss: 0.9660 - val_categorical_accuracy: 0.6017
# Epoch 23/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.3494 - categorical_accuracy: 0.9065 - val_loss: 1.1325 - val_categorical_accuracy: 0.5678
# Epoch 24/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.3050 - categorical_accuracy: 0.9263 - val_loss: 1.0954 - val_categorical_accuracy: 0.5847
# Epoch 25/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.2687 - categorical_accuracy: 0.9490 - val_loss: 1.2152 - val_categorical_accuracy: 0.5932
# Epoch 26/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.2431 - categorical_accuracy: 0.9575 - val_loss: 1.3446 - val_categorical_accuracy: 0.5593
# Epoch 27/50
# 12/12 [==============================] - 16s 1s/step - loss: 0.2475 - categorical_accuracy: 0.9320 - val_loss: 1.2789 - val_categorical_accuracy: 0.6017
# Restoring model weights from the end of the best epoch.
# Epoch 00027: early stopping
# Score for fold 5: loss of 0.9348123669624329; categorical_accuracy of 57.26495981216431%

# %% [markdown]
# **Provide average scores**

# %%
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.9467569589614868 - Accuracy: 51.69491767883301%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.8705316185951233 - Accuracy: 63.55932354927063%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.8849905729293823 - Accuracy: 65.25423526763916%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.8941837549209595 - Accuracy: 61.538463830947876%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.9348123669624329 - Accuracy: 57.26495981216431%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 59.862380027770996 (+- 4.8785814381208334)
# > Loss: 0.906255054473877
# ------------------------------------------------------------------------
